# %%
import sys, os
import numpy as np
# %matplotlib notebook
import matplotlib.pyplot as plt
import pydub
import torch
from torchvision.datasets import MNIST
from torchvision import transforms
import torch.nn as nn
from datasets import *
from loading import load_model
#import torchaudio
#from torchaudio import transforms
import h5py as hf

# %%
#root = 'trained_nets/gan-jmel-gain5-1000-jstep5-jclip03-genlayers2-norm-lr4_18-12-07-010850/'#checkpoint_20.pth.tar'
root = 'trained_nets/gan-mel-gain5-1000-jstep5-jclip01-norm_18-12-06-041401/'

name = 'checkpoint_{}.pth.tar'.format(50)
name = 'best.pth.tar'
path = os.path.join(root, name)

# %%
model = load_model(path)
ckpt = torch.load(path)
print(model)
ckpt.keys()
# Out:
# Traceback (most recent call last):
#   File "/home/fleeb/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3267, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-042adc184249>", line 1, in <module>
#     model = load_model(path)
#   File "/home/fleeb/workspace/marl/foundation/carotid/loading.py", line 17, in load_model
#     checkpoint = torch.load(path)
#   File "/home/fleeb/anaconda3/lib/python3.6/site-packages/torch/serialization.py", line 358, in load
#     return _load(f, map_location, pickle_module)
#   File "/home/fleeb/anaconda3/lib/python3.6/site-packages/torch/serialization.py", line 542, in _load
#     result = unpickler.load()
#   File "/home/fleeb/anaconda3/lib/python3.6/site-packages/torch/serialization.py", line 508, in persistent_load
#     data_type(size), location)
#   File "/home/fleeb/anaconda3/lib/python3.6/site-packages/torch/serialization.py", line 104, in default_restore_location
#     result = fn(storage, location)
#   File "/home/fleeb/anaconda3/lib/python3.6/site-packages/torch/serialization.py", line 86, in _cuda_deserialize
#     return obj.cuda(device)
#   File "/home/fleeb/anaconda3/lib/python3.6/site-packages/torch/_utils.py", line 76, in _cuda
#     return new_type(self.size()).copy_(self, non_blocking)
#   File "/home/fleeb/anaconda3/lib/python3.6/site-packages/torch/cuda/__init__.py", line 495, in _lazy_new
#     return super(_CudaBase, cls).__new__(cls, *args, **kwargs)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/fleeb/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2018, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/fleeb/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1095, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/fleeb/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 313, in wrapped
#     return f(*args, **kwargs)
#   File "/home/fleeb/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 347, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/fleeb/anaconda3/lib/python3.6/inspect.py", line 1483, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/fleeb/anaconda3/lib/python3.6/inspect.py", line 1441, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/fleeb/anaconda3/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/home/fleeb/anaconda3/lib/python3.6/inspect.py", line 739, in getmodule
#     f = getabsfile(module)
#   File "/home/fleeb/anaconda3/lib/python3.6/inspect.py", line 709, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/home/fleeb/anaconda3/lib/python3.6/posixpath.py", line 376, in abspath
#     return normpath(path)
#   File "/home/fleeb/anaconda3/lib/python3.6/posixpath.py", line 348, in normpath
#     path.startswith(sep*2) and not path.startswith(sep*3)):
# KeyboardInterrupt
# -------------------------

# %%
weights = model[0].conv[0].weight.clone().detach().cpu()
weights.size()

# %%
i = 0
N = 10

# %%
fig, axes = plt.subplots(N, figsize=(4,8))
for j, (ax, w) in enumerate(zip(axes.flat, weights[i:].squeeze())):
    ax.plot(w.numpy())
    ax.set_title(str(i+j))
    ax.axis('off')
#fig.tight_layout()
i += N
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
good_ones = [49, 68, 60,
             78, 85, 26,
             124, 20, 12,
             #21,  69, 52,
            ]
M = min(12, len(good_ones)) #len(good_ones) - 1

# %%
fig, axes = plt.subplots(3, 3, figsize=(8,4))
for j, (ax, w) in enumerate(zip(axes.flat, weights[good_ones].squeeze())):
    ax.plot(np.zeros(w.shape[0]), c='k')
    ax.plot(w.numpy())
    
    #ax.set_title(str(i+j))
    ax.set_xticks([])
    ax.set_yticks([])
    #ax.axis('off')
fig.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# fig.savefig('results/gan-weights.png')
# fig.savefig('results/gan-weights.pdf')

# %%
def parameter_count(module):
    s = sum([np.prod(d.size()) for d in module.parameters()])
    return s

# %%
root = 'trained_nets/'

# %%
model_paths = [p for p in os.listdir(root) if 'gan' in p]
names = [p[:p.find('_')] for p in model_paths]
model_paths = [os.path.join(root, p) for p in model_paths]
names
# Out:
# ['gan-mel-gain5-1000-jstep5-jclip01-nobias',
#  'gan-mel-3000-jstep5-jclip01',
#  'gan-mel-gain5-3000-jstep5-jclip01',
#  'gan-jstep2-jclip01',
#  'gan-mel-gain5-1000-jstep5-jclip01-norm',
#  'gan-mel-gain6-1000-jstep5-jclip01',
#  'gan-jmel-gain5-1000-jstep5-jclip03-genlayers2-norm',
#  'gan-jmel-gain5-1000-jstep3-jclip03-genlayers2-norm-lr4',
#  'gan-mel-1000-jstep2-jclip01',
#  'gan-3sec-rmsprop',
#  'gan-jmel-gain5-3000-jstep5-jclip01-genlayers3',
#  'gan-mel-gain5-3000-jstep5-jclip01-norm',
#  'gan-jmel-gain5-1000-jstep5-jclip03-genlayers2-norm-lr4',
#  'gan-jmel-gain5-3000-jstep5-jclip01-genlayers2-norm',
#  'gan-jmel-gain5-1000-jstep5-jclip01-genlayers3-norm',
#  'gan-3sec-clip04-rmsprop',
#  'gan-jmel-gain5-1000-jstep5-jclip01-genlayers4',
#  'gan-jmel-gain5-2000-jstep5-jclip03-genlayers2-norm-lr4',
#  'gan-jmel-gain5-1000-jstep5-jclip01-genlayers4-norm-lstm',
#  'test-gan-jmel-gain5-1000-jstep5-jclip03-genlayers2-norm-lr4-lstm',
#  'gan-jmel-gain5-1000-jstep5-jclip03-genlayers2-lr4',
#  'gan-jmel-gain5-1000-jstep5-jclip03-genlayers3-norm-lr4',
#  'gan-mel-gain5-1000-jstep5-jclip01',
#  'gan-jmel-gain5-3000-jstep5-jclip03-genlayers2-norm-lr4',
#  'gan-jstep5-jclip01-hop500',
#  'gan-jmel-gain5-3000-jstep5-jclip03-genlayers3-norm',
#  'gan-jmel-gain5-1000-jstep5-jclip03-genlayers2-norm-lr4-lstm',
#  'gan-mel-1000-jstep5-jclip01-clamp-trial2',
#  'gan-jmel-gain5-1000-jstep5-jclip01-genlayers2-norm-lr5e-3',
#  'gan-jmel-gain5-3000-jstep5-jclip03-genlayers2-norm-lr4',
#  'gan-jmel-gain5-1000-jstep5-jclip01-genlayers3-norm-lstm',
#  'gan-jmel-gain5-3000-jstep5-jclip03-genlayers3-norm-lr5e-3',
#  'gan-jstep1-jclip01',
#  'gan-mel-1000-jstep5-jclip01-clamp',
#  'gan-jmel-gain5-1000-jstep5-jclip03-genlayers2-norm-lr4',
#  'gan-mel-1000-jstep5-jclip01-cls',
#  'gan-jstep2-jclip01-cls',
#  'gan-jstep2-jclip04',
#  'gan-3sec-rmsprop-clip02',
#  'gan-jmel-gain5-3000-jstep5-jclip03-genlayers3-norm-lr4',
#  'gan-jmel-gain5-1000-jstep5-jclip03-genlayers2-norm-lr4-cls',
#  'gan-mel-gain6-3000-jstep5-jclip01',
#  'gan-mel-1000-jstep5-jclip01',
#  'gan-mel-gain5-1000-jstep5-jclip01-cls',
#  'gan-mel-gain6-1000-jstep5-jclip01-cls']

# %%
for name, path in zip(names, model_paths):
    try:
        model = load_model(path)
    except:
        continue
    num = parameter_count(model)
    print('{} : {}'.format(name, num))
# Out:
# Loaded trained_nets/gan-mel-gain5-1000-jstep5-jclip01-nobias_18-12-06-155249/best.pth.tar
# Norm: False
# Saved params loaded
# gan-mel-gain5-1000-jstep5-jclip01-nobias : 2981122
# Loaded trained_nets/gan-mel-3000-jstep5-jclip01_18-12-05-225018/best.pth.tar
# Norm: False
# Saved params loaded
# gan-mel-3000-jstep5-jclip01 : 2981122
# Loaded trained_nets/gan-jstep2-jclip01_18-12-05-033729/best.pth.tar
# Saved params loaded
# gan-jstep2-jclip01 : 1662621
# Loaded trained_nets/gan-mel-gain5-1000-jstep5-jclip01-norm_18-12-06-041401/best.pth.tar
# Norm: True
# Saved params loaded
# gan-mel-gain5-1000-jstep5-jclip01-norm : 2981122
# Loaded trained_nets/gan-jmel-gain5-1000-jstep5-jclip03-genlayers2-norm_18-12-07-010453/best.pth.tar
# Norm: True
# Saved params loaded
# gan-jmel-gain5-1000-jstep5-jclip03-genlayers2-norm : 3352833
# Loaded trained_nets/gan-jmel-gain5-1000-jstep3-jclip03-genlayers2-norm-lr4_18-12-07-100826/best.pth.tar
# Norm: True
# Saved params loaded
# gan-jmel-gain5-1000-jstep3-jclip03-genlayers2-norm-lr4 : 2514689
# Loaded trained_nets/gan-mel-1000-jstep2-jclip01_18-12-05-222130/best.pth.tar
# Norm: False
# Saved params loaded
# gan-mel-1000-jstep2-jclip01 : 2981122
# Loaded trained_nets/gan-3sec-rmsprop_18-12-05-002402/best.pth.tar
# Saved params loaded
# gan-3sec-rmsprop : 1662621
# Loaded trained_nets/gan-jmel-gain5-3000-jstep5-jclip01-genlayers3_18-12-06-174911/best.pth.tar
# Norm: False
# Saved params loaded
# gan-jmel-gain5-3000-jstep5-jclip01-genlayers3 : 3401729
# Loaded trained_nets/gan-mel-gain5-3000-jstep5-jclip01-norm_18-12-06-041504/best.pth.tar
# Norm: True
# Saved params loaded
# gan-mel-gain5-3000-jstep5-jclip01-norm : 2981122
# Loaded trained_nets/gan-jmel-gain5-1000-jstep5-jclip03-genlayers2-norm-lr4_18-12-07-010850/best.pth.tar
# Norm: True
# Saved params loaded
# gan-jmel-gain5-1000-jstep5-jclip03-genlayers2-norm-lr4 : 2514689
# Loaded trained_nets/gan-jmel-gain5-3000-jstep5-jclip01-genlayers2-norm_18-12-07-010053/best.pth.tar
# Norm: True
# Saved params loaded
# gan-jmel-gain5-3000-jstep5-jclip01-genlayers2-norm : 2514689
# Loaded trained_nets/gan-jmel-gain5-1000-jstep5-jclip01-genlayers3-norm_18-12-06-195523/best.pth.tar
# Norm: True
# Saved params loaded
# gan-jmel-gain5-1000-jstep5-jclip01-genlayers3-norm : 3401729
# Loaded trained_nets/gan-3sec-clip04-rmsprop_18-12-05-002336/best.pth.tar
# Saved params loaded
# gan-3sec-clip04-rmsprop : 1662621
# Loaded trained_nets/gan-jmel-gain5-1000-jstep5-jclip01-genlayers4_18-12-06-173557/best.pth.tar
# Norm: False
# Saved params loaded
# gan-jmel-gain5-1000-jstep5-jclip01-genlayers4 : 4288769
# Loaded trained_nets/gan-jmel-gain5-2000-jstep5-jclip03-genlayers2-norm-lr4_18-12-07-150506/best.pth.tar
# Norm: True
# Saved params loaded
# gan-jmel-gain5-2000-jstep5-jclip03-genlayers2-norm-lr4 : 2514689
# Loaded trained_nets/gan-jmel-gain5-1000-jstep5-jclip01-genlayers4-norm-lstm_18-12-07-010254/best.pth.tar
# Norm: True
# Saved params loaded
# gan-jmel-gain5-1000-jstep5-jclip01-genlayers4-norm-lstm : 5718273
# Loaded trained_nets/gan-jmel-gain5-1000-jstep5-jclip03-genlayers2-lr4_18-12-07-101054/best.pth.tar
# Norm: False
# Saved params loaded
# gan-jmel-gain5-1000-jstep5-jclip03-genlayers2-lr4 : 2514689
# Loaded trained_nets/gan-jmel-gain5-1000-jstep5-jclip03-genlayers3-norm-lr4_18-12-07-150421/best.pth.tar
# Norm: True
# Saved params loaded
# gan-jmel-gain5-1000-jstep5-jclip03-genlayers3-norm-lr4 : 3401729
# Loaded trained_nets/gan-mel-gain5-1000-jstep5-jclip01_18-12-06-035652/best.pth.tar
# Norm: False
# Saved params loaded
# gan-mel-gain5-1000-jstep5-jclip01 : 2981122
# Loaded trained_nets/gan-jmel-gain5-3000-jstep5-jclip03-genlayers2-norm-lr4_18-12-07-102437/best.pth.tar
# Norm: True
# Saved params loaded
# gan-jmel-gain5-3000-jstep5-jclip03-genlayers2-norm-lr4 : 2514689
# Loaded trained_nets/gan-jstep5-jclip01-hop500_18-12-05-033729/best.pth.tar
# Saved params loaded
# gan-jstep5-jclip01-hop500 : 1662621
# Loaded trained_nets/gan-jmel-gain5-3000-jstep5-jclip03-genlayers3-norm_18-12-07-011039/best.pth.tar
# Norm: True
# Saved params loaded
# gan-jmel-gain5-3000-jstep5-jclip03-genlayers3-norm : 4535553
# Loaded trained_nets/gan-jmel-gain5-1000-jstep5-jclip03-genlayers2-norm-lr4-lstm_18-12-07-100719/best.pth.tar
# Norm: True
# Saved params loaded
# gan-jmel-gain5-1000-jstep5-jclip03-genlayers2-norm-lr4-lstm : 3352833
# Loaded trained_nets/gan-mel-1000-jstep5-jclip01-clamp-trial2_18-12-06-010531/best.pth.tar
# Norm: False
# Saved params loaded
# gan-mel-1000-jstep5-jclip01-clamp-trial2 : 2981122
# Loaded trained_nets/gan-jmel-gain5-1000-jstep5-jclip01-genlayers2-norm-lr5e-3_18-12-07-100519/best.pth.tar
# Norm: True
# Saved params loaded
# gan-jmel-gain5-1000-jstep5-jclip01-genlayers2-norm-lr5e-3 : 2514689
# Loaded trained_nets/gan-jmel-gain5-3000-jstep5-jclip03-genlayers2-norm-lr4_18-12-07-100317/best.pth.tar
# Norm: True
# Saved params loaded
# gan-jmel-gain5-3000-jstep5-jclip03-genlayers2-norm-lr4 : 2514689
# Loaded trained_nets/gan-jmel-gain5-1000-jstep5-jclip01-genlayers3-norm-lstm_18-12-07-010053/best.pth.tar
# Norm: True
# Saved params loaded
# gan-jmel-gain5-1000-jstep5-jclip01-genlayers3-norm-lstm : 3352833
# Loaded trained_nets/gan-jstep1-jclip01_18-12-05-033729/best.pth.tar
# Saved params loaded
# gan-jstep1-jclip01 : 1662621
# Loaded trained_nets/gan-mel-1000-jstep5-jclip01-clamp_18-12-05-231537/best.pth.tar
# Norm: False
# Saved params loaded
# gan-mel-1000-jstep5-jclip01-clamp : 2981122
# Loaded trained_nets/gan-jmel-gain5-1000-jstep5-jclip03-genlayers2-norm-lr4_18-12-07-102547/best.pth.tar
# Norm: True
# Saved params loaded
# gan-jmel-gain5-1000-jstep5-jclip03-genlayers2-norm-lr4 : 2514689
# Loaded trained_nets/gan-mel-1000-jstep5-jclip01-cls_18-12-06-004850/best.pth.tar
# Norm: False
# Saved params loaded
# gan-mel-1000-jstep5-jclip01-cls : 3008002
# Loaded trained_nets/gan-jstep2-jclip01-cls_18-12-05-135239/best.pth.tar
# Saved params loaded
# gan-jstep2-jclip01-cls : 1678749
# Loaded trained_nets/gan-jstep2-jclip04_18-12-05-135431/best.pth.tar
# Saved params loaded
# gan-jstep2-jclip04 : 1662621
# Loaded trained_nets/gan-3sec-rmsprop-clip02_18-12-05-010625/best.pth.tar
# Saved params loaded
# gan-3sec-rmsprop-clip02 : 1662621
# Loaded trained_nets/gan-jmel-gain5-3000-jstep5-jclip03-genlayers3-norm-lr4_18-12-07-100347/best.pth.tar
# Norm: True
# Saved params loaded
# gan-jmel-gain5-3000-jstep5-jclip03-genlayers3-norm-lr4 : 3401729
# Loaded trained_nets/gan-jmel-gain5-1000-jstep5-jclip03-genlayers2-norm-lr4-cls_18-12-07-160719/best.pth.tar
# Norm: True
# Saved params loaded
# gan-jmel-gain5-1000-jstep5-jclip03-genlayers2-norm-lr4-cls : 2541569
# Loaded trained_nets/gan-mel-1000-jstep5-jclip01_18-12-05-222751/best.pth.tar
# Norm: False
# Saved params loaded
# gan-mel-1000-jstep5-jclip01 : 2981122
# Loaded trained_nets/gan-mel-gain5-1000-jstep5-jclip01-cls_18-12-06-035629/best.pth.tar
# Norm: False
# Saved params loaded
# gan-mel-gain5-1000-jstep5-jclip01-cls : 3008002
# Loaded trained_nets/gan-mel-gain6-1000-jstep5-jclip01-cls_18-12-06-034713/best.pth.tar
# Norm: False
# Saved params loaded
# gan-mel-gain6-1000-jstep5-jclip01-cls : 3008002

# %%
#root = 'trained_nets/gan-jmel-gain5-1000-jstep5-jclip03-genlayers2-norm-lr4-cls_18-12-07-160719/'
root = 'trained_nets/gan-jmel-gain5-1000-jstep5-jclip03-genlayers2-norm-lr4_18-12-07-102547/'
#root = 'trained_nets/gan-jmel-gain5-1000-jstep5-jclip03-genlayers2-norm-lr4_18-12-07-102547/'
#root = 'trained_nets/gan-jmel-gain5-3000-jstep5-jclip03-genlayers2-norm-lr4_18-12-07-102437'
name = 'checkpoint_{}.pth.tar'.format(8)
#name = 'best.pth.tar'
path = os.path.join(root, name)

# %%
emodel = load_model(path)
ckpt = torch.load(path)
print(model)
ckpt.keys()
# Out:
# Loaded trained_nets/gan-jmel-gain5-1000-jstep5-jclip03-genlayers2-norm-lr4_18-12-07-102547/checkpoint_8.pth.tar
# Norm: True
# Saved params loaded
# ModuleList(
#   (0): MEL_Discriminator(
#     (rec): RecNet(
#       (rec): GRU(384, 256, num_layers=2, batch_first=True)
#       (out_layer): Linear(in_features=256, out_features=1, bias=True)
#     )
#   )
#   (1): MEL_Generator(
#     (inventor): RecNet(
#       (rec): GRU(256, 384, num_layers=2, batch_first=True)
#     )
#     (spec): MEL_Spectrogram()
#   )
# )
# dict_keys(['epoch', 'args', 'best_loss', 'best_epoch', 'train_stats', 'train_data', 'test_data', 'model_state', 'j_optim_state', 'g_optim_state'])

# %%
name = 'checkpoint_{}.pth.tar'.format(48)
#name = 'best.pth.tar'
path = os.path.join(root, name)
lmodel = load_model(path)
ckpt = torch.load(path)
print(lmodel)
ckpt.keys()
# Out:
# Loaded trained_nets/gan-jmel-gain5-1000-jstep5-jclip03-genlayers2-norm-lr4_18-12-07-102547/checkpoint_48.pth.tar
# Norm: True
# Saved params loaded
# ModuleList(
#   (0): MEL_Discriminator(
#     (rec): RecNet(
#       (rec): GRU(384, 256, num_layers=2, batch_first=True)
#       (out_layer): Linear(in_features=256, out_features=1, bias=True)
#     )
#   )
#   (1): MEL_Generator(
#     (inventor): RecNet(
#       (rec): GRU(256, 384, num_layers=2, batch_first=True)
#     )
#     (spec): MEL_Spectrogram()
#   )
# )
# dict_keys(['epoch', 'args', 'best_loss', 'best_epoch', 'train_stats', 'train_data', 'test_data', 'model_state', 'j_optim_state', 'g_optim_state'])

# %%
model = lmodel
#model = emodel

# %%
parameter_count(model)
# Out:
# 2514689

# %%
gen = model[1]
print(gen, gen.ret_mel)
# Out:
# MEL_Generator(
#   (inventor): RecNet(
#     (rec): GRU(256, 384, num_layers=2, batch_first=True)
#   )
#   (spec): MEL_Spectrogram()
# ) True

# %%
gen.ret_mel = False

# %%
gen.seq_len
# Out:
# 44100

# %%
true_data = ckpt['train_data']
len(true_data), true_data.seq_len
# Out:
# (194993, 882000)

# %%
seq_len = 20000 # ms

# %%
true_data.seq_len = seq_len * 44100 // 1000
true = true_data[170000][0] # 12300 170000
true2 = true_data[12300][0]
true.shape
# Out:
# (882000,)

# %%
audio = gen(num=1, seq_len=seq_len)
audio.size(), audio.size(-1) / 44100
# Out:
# (torch.Size([1, 1, 882000]), 20.0)

# %%
mel = gen.mel.t()
mel.size()

# %%
gen.mel.size(), gen.mel.max()
# Out:
# (torch.Size([1, 501, 128]),
#  tensor(4.9925, device='cuda:0', grad_fn=<MaxBackward1>))

# %%
#pmel2 = gen.mel

# %%
plt.figure()
plt.imshow(gen.mel[0].detach().cpu().numpy())
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
mel, phase = gen.spec(torch.from_numpy(true).unsqueeze(0).cuda().float(), ret_phase=True)
#tmel2 = mel
mel.size(), phase.size()
# Out:
# (torch.Size([1, 128, 500]), torch.Size([1, 128, 500]))

# %%
plt.figure()
plt.imshow(mel[0].detach().cpu().numpy())
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
tmel1.size(), tmel2.size()
# Out:
# (torch.Size([1, 128, 500]), torch.Size([1, 128, 500]))

# %%
#pmel1, pmel2 = pmel1[0].t(), pmel2[0].t()
#tmel1, tmel2 = tmel1[0], tmel2[0]

# %%
imgs = [
    pmel1, pmel2,
    tmel1, tmel2,
]
titles = [
    'A', 'B', 'C', 'D',
]

# %%
fig, axes = plt.subplots(2,2, figsize=(8,3))

for t, img, ax in zip(titles, imgs, axes.flat):
    
    plt.sca(ax)
    plt.text(10,30,s=t, color='r', size=16)
    #plt.title(t)
    plt.imshow(img.detach().cpu().numpy())
    plt.xticks([])
    plt.yticks([])
    plt.axis('off')
fig.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
#fig.savefig('results/specs.png')
#fig.savefig('results/specs.pdf')

# %%
#plt.figure()
#plt.imshow(gen.phase[0].detach().cpu().numpy())

# %%
plt.figure()
plt.plot(audio[0,0].cpu().detach().numpy())
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.plot(true)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
tseg = samples2audio(true.astype(np.float32))
tseg.duration_seconds, tseg.rms, tseg.dBFS
# Out:
# (3.0, 6811, -13.644781093542182)

# %%
seg = samples2audio(audio[0,0].detach().cpu().numpy())
seg.duration_seconds
# Out:
# 10.0

# %%
#ref = np.sin(np.linspace(0,100*2*np.pi, num=44100))

# %%
seg.rms, seg.dBFS
# Out:
# (3076, -20.54927207660649)

# %%
s2 = pydub.effects.normalize(seg)
s2.rms, s2.dBFS
# Out:
# (3937, -18.405690403389766)

# %%
#tseg.export('control.mp3', format='mp3')
#seg.export('gen8.mp3', format='mp3')
#s2.export('gen8-norm.mp3', format='mp3')
# Out:
# <_io.BufferedRandom name='gen8-norm.mp3'>

# %%
x = s2.apply_gain_stereo(0)
x.rms, x.dBFS
# Out:
# (17306, -5.5450647116140805)

# %%
x = x.apply_gain_stereo(-3)
x.rms, x.dBFS
# Out:
# (14039, -7.362275218459605)

# %%
true = ckpt['train_data'][2][0]
true.shape
# Out:
# (44100,)

# %%
x = audio[0,0].detach().cpu().numpy().copy()#*2
#x = true.copy() #ref.copy()#/2
x.shape
# Out:
# (220500,)

# %%
rms = np.sqrt((x**2).mean())
rms
# Out:
# 1.0098447

# %%
20*np.log10(rms)
# Out:
# 0.0850914791226387

# %%
np.sqrt((x**2).mean()) * 2**15
# Out:
# 33090.58984375

# %%
s = samples2audio(x.astype(np.float32))
s.rms, s.dBFS
# Out:
# (4993, -16.34176737809216)

# %%
s.dBFS
# Out:
# -16.34176737809216

# %%
#tseg.apply_gain(-14 - (-13.535)).dBFS

# %%
s.max
# Out:
# 25082

# %%
from pydub.utils import db_to_float, ratio_to_db

# %%
db_to_float(-3)
# Out:
# 0.7079457843841379

# %%
(x==0).sum()
# Out:
# 6

# %%
20*np.log10(rms)
# Out:
# -16.340313441135358

# %%
10*np.log10(np.square(x+1e-10))
# Out:
# -16.340313441133492
