# %%
import sys, os
import numpy as np
# %matplotlib notebook
import matplotlib.pyplot as plt
import pydub
import torch

# %%
def crawl(d, cond):
    if os.path.isdir(d):
        options = []
        for f in os.listdir(d):
            path = os.path.join(d, f)
            options.extend(crawl(path, cond))
        return options
    if cond(d):
        return [d]
    return []

# %%
audio_files = crawl('/home/fleeb/workspace/ml_datasets/audio/yt/test', lambda x: '.mp3' in x)
print(len(audio_files))
for n in audio_files:
    print(n)
# Out:
# 7
# /home/fleeb/workspace/ml_datasets/audio/yt/test/[No Copyright Music] Talking With You - Artificial Music.mp3
# /home/fleeb/workspace/ml_datasets/audio/yt/test/[No Copyright Music] Spring Autumn Sunset - Artificial.Music.mp3
# /home/fleeb/workspace/ml_datasets/audio/yt/test/[No Copyright Music] And So It Begins - Artificial Music.mp3
# /home/fleeb/workspace/ml_datasets/audio/yt/test/[No Copyright Music] Alone, Two Days Ago - Artificial.Music.mp3
# /home/fleeb/workspace/ml_datasets/audio/yt/test/[No Copyright Music] herbal tea - Artificial.Music.mp3
# /home/fleeb/workspace/ml_datasets/audio/yt/test/[No Copyright Music] In The Light - Artificial Music.mp3
# /home/fleeb/workspace/ml_datasets/audio/yt/test/[No Copyright Music] Where Are We - Artificial.Music.mp3

# %%
s = pydub.AudioSegment.from_file(audio_files[0])
print('length: {:.4f} min'.format(len(s) / 60 / 1000))
# Out:
# length: 3.0274 min

# %%
len(s.raw_data) / s.frame_rate / s.channels / s.sample_width # 16bit
# Out:
# 181.64460416666665

# %%
s.channels
# Out:
# 2

# %%
s.sample_width
# Out:
# 2

# %%
x = pydub.effects.normalize(s)

# %%
y = pydub.effects.normalize(x)

# %%
s.rms, x.rms, y.rms
# Out:
# (7911, 7821, 7821)

# %%
left, right = s.split_to_mono()

# %%
left.rms
# Out:
# 7931

# %%
x = pydub.effects.normalize(left)
x.rms
# Out:
# 7840

# %%
a = np.frombuffer(left.raw_data, dtype=np.int16) / 2**15
a.dtype, a.shape
# Out:
# (dtype('float64'), (8718941,))

# %%
begin, end = np.where(a != 0)[0][[0, -1]]

# %%
np.where?

# %%
plt.figure()
plt.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
spec = np.fft.fft(a)
spec = np.abs(spec)
spec = spec[:len(spec)//2]
fs = right.frame_rate
w = np.arange(len(spec)) * fs / len(spec) / 2

# %%
fs / len(spec)
# Out:
# 0.06666666666666667

# %%
x = w[w<5000]
y = spec[w<5000]

# %%
plt.figure()
plt.plot(x, y)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
t = torch.tensor(a)
t.size()
# Out:
# torch.Size([1323000])

# %%
torch.stft?

# %%
spec = torch.stft(t, 3000, 3000).pow(2).sum(-1).sqrt()
spec.size()
# Out:
# torch.Size([441, 1501])

# %%
plt.figure()
plt.imshow(spec.numpy()[:,:200:2].T)
# Out:
# <img src="data:image/png;base64,..." width="640">
