# %%
import sys, os, time
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import torch
from foundation import util

# %%
paths = util.crawl('/home/fleeb/workspace/ml_datasets/places365/', lambda x: '.jpg' in x)
len(paths)
# Out:
# 1839960

# %%
path = paths[10]

# %%
img = util.get_img(path)
img.shape, np.product(img.shape)
# Out:
# ((512, 842, 3), 1293312)

# %%
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 841.5, 511.5, -0.5)

# %%
s = util.rgb_to_str(img)
len(s)
# Out:
# 444366

# %%
os.path.getsize(path)
# Out:
# 47443

# %%
path
# Out:
# '/home/fleeb/workspace/ml_datasets/places365/validation/val_large/Places365_val_00035000.jpg'
